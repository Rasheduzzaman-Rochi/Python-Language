# %%
def calculate_final_price(price):
    tax_rate = 0.08
    final_price = price + (price * tax_rate)
    print(f"The final price is: ${final_price:.2f}")

calculate_final_price(100)
calculate_final_price(50)
calculate_final_price(25.5)
# Out:
# The final price is: $108.00
# The final price is: $54.00
# The final price is: $27.54
