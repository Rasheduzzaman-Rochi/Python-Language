# %%
import numpy as np

# %%
a = np.array([2,4,6])
print(a)
a.ndim
a.dtype
# a.itemsize
# Out:
# [2 4 6]
# dtype('int64')

# %%
b = np.array([[9.0,8.0,7.0],[6.0,5.0,4.0]])
print(b)
b.ndim
b.shape
# b.itemsize
# Out:
# [[9. 8. 7.]
#  [6. 5. 4.]]
# (2, 3)
